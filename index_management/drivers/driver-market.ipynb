# %%
from index_management.market.Manager import Market

# %%
dates = [20250331] #20231231, 20240331,20240630,20240930,20241231,

for date in dates[-1:]:
    mkt = Market(date)
    mkt.get_caps()
    mkt.get_prices()
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/UBLB.F?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=UBLB.F&crumb=Yq4XF%2F%2FcCHu
# YF.download() has changed argument auto_adjust default to True
# [                       0%                       ]
# [*****                 10%                       ]  4 of 40 completed
# [*****                 10%                       ]  4 of 40 completed
# [*********             18%                       ]  7 of 40 completed
# [**********            20%                       ]  8 of 40 completed
# [************          25%                       ]  10 of 40 completed
# [*************         28%                       ]  11 of 40 completed
# [**************        30%                       ]  12 of 40 completed
# [***************       32%                       ]  13 of 40 completed
# ...

# %%
mkt = Market(20250410)
mkt.get_daily_prices()
# Out:
# [                       0%                       ]
# [**                     5%                       ]  2 of 40 completed
# [****                   8%                       ]  3 of 40 completed
# [****                   8%                       ]  3 of 40 completed
# [****                   8%                       ]  3 of 40 completed
# [*******               15%                       ]  6 of 40 completed
# [*********             18%                       ]  7 of 40 completed
# [***********           22%                       ]  9 of 40 completed
# [************          25%                       ]  10 of 40 completed
# [*************         28%                       ]  11 of 40 completed
# [**************        30%                       ]  12 of 40 completed
# [***************       32%                       ]  13 of 40 completed
# [*****************     35%                       ]  14 of 40 completed
# [******************    38%                       ]  15 of 40 completed
# ...
